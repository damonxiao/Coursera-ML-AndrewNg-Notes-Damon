# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Thu Mar 14 16:47:04 2019

@author: xiaofang
"""

import tensorflow as tf

tf.reset_default_graph()

with tf.variable_scope("test1"):
    var1 = tf.get_variable("firstvar", shape=[2], dtype=tf.float32)
    with tf.variable_scope("test2"):
        var2 = tf.get_variable("firstvar", shape=[2], dtype=tf.float32)

print("var1:", var1.name)
print("var2:", var2.name)
# Out:
# var1: test1/firstvar:0
# var2: test1/test2/firstvar:0

# %% [markdown]
# 下边代码片断与上边的scope使用了相同的scope名字test1,必须要添加reuse=True,否则报错如下,或者要在变量scope之前调用tf.reset_default_graph()
# ![image.png](attachment:image.png)

# %%
# with tf.variable_scope("test1"):
with tf.variable_scope("test1", reuse=True):
    var3 = tf.get_variable("firstvar", shape=[2], dtype=tf.float32)
    with tf.variable_scope("test2"):
        var4 = tf.get_variable("firstvar", shape=[2], dtype=tf.float32)

print("var3:", var3.name)
print("var4:", var4.name)
# Out:
# var3: test1/firstvar:0
# var4: test1/test2/firstvar:0

# %% [markdown]
# 从上边的代码片段可以看出,利用了相同的scope的var3和var4的变量名和之前的var1,var2变量名相同

# %%
with tf.variable_scope("test_scope_1", ):
    var1 = tf.get_variable("firstvar",shape=[2],dtype=tf.float32)
    
with tf.variable_scope("test_scope_2"):
    var2 = tf.get_variable("firstvar",shape=[2],dtype=tf.float32)
        
print ("var1:",var1.name)
print ("var2:",var2.name)
# Out:
# var1: test_scope_1/firstvar:0
# var2: test_scope_2/firstvar:0
